# %%
import pandas as pd
import requests
import json

# %%
mycoins = ['ANC', 'ATLAS', 'AXS', 'BCMC', 'BCOIN', 'BNB', 'BTC', 'BUSD', 'CAKE', 'ETH', 'HIGH', 'ILV', 'MATIC', 'MC', 'MYST', 'POLIS', 'PRL', 'SOL', 'TITA', 'USDC', 'USDT', 'SAND', 'APE', 'WAN', 'MBOX', 'SEN']

# %%
url = "https://api.4kings.xyz/v1/crypto"
response = requests.request("GET", url)
print(response.text)
# Out:
# [{"atl_3m":26350.4901742248,"atl_1m":26350.4901742248,"github":"https://github.com/bitcoin/bitcoin","ath_date_3m":"2022-03-28T00:00:00.000Z","ath_date_1m":"2022-04-22T00:00:00.000Z","atl_date_1w":"2022-05-19T00:00:00.000Z","ath_date_1w":"2022-05-15T00:00:00.000Z","latest_atl_date":"2022-05-08T00:00:00.000Z","change_60d":-1.02,"atl_1w":28708.9550418266,"name":"Bitcoin","change_24h":0.23,"change_30d":0.49,"atl_date_1m":"2022-05-12T00:00:00.000Z","change_ath":-74.91,"atl_date_3m":"2022-05-12T00:00:00.000Z","ath_date":"2021-11-10T14:17:02.000Z","circulating_supply":19257737,"latest_atl":33878.9645692059,"id":1,"max_supply":21000000,"change_7d":3.21,"tags":["mineable","pow","sha-256","store-of-value","state-channel","coinbase-ventures-portfolio","three-arrows-capital-portfolio","polychain-capital-portfolio","binance-labs-portfolio","blockchain-capital-portfolio","boostvc-portfolio","cms-holdings-portfolio","dcg-portfolio","dragonfly-capital-portfolio","electric-capital-portfolio","fabric-
# ...

# %%
url = "https://app.4kings.xyz/api/exchanges/list"
response = requests.request("GET", url)
print(response.text)
# Out:
# {"last_updated":"2022-03-27T07:41:38Z","data":{"btc":[{"id":270,"name":"Binance"},{"id":294,"name":"OKX"},{"id":538,"name":"CoinFLEX"},{"id":943,"name":"Hotcoin Global"},{"id":391,"name":"CoinTiger"},{"id":521,"name":"Bybit"},{"id":1563,"name":"BTCEX"},{"id":524,"name":"FTX"},{"id":513,"name":"Bitget"},{"id":407,"name":"DigiFinex"},{"id":1064,"name":"BingX"},{"id":1149,"name":"Crypto.com Exchange"},{"id":311,"name":"KuCoin"},{"id":302,"name":"Gate.io"},{"id":102,"name":"Huobi Global"},{"id":1507,"name":"BitCoke"},{"id":351,"name":"Upbit"},{"id":42,"name":"HitBTC"},{"id":1182,"name":"Deepcoin"},{"id":89,"name":"Coinbase Exchange"},{"id":587,"name":"IndoEx"},{"id":865,"name":"TOKENCAN"},{"id":544,"name":"MEXC"},{"id":955,"name":"Phemex"},{"id":857,"name":"FMFW.io"},{"id":433,"name":"Bitrue"},{"id":1128,"name":"Changelly PRO"},{"id":790,"name":"Pionex"},{"id":517,"name":"CoinW"},{"id":1186,"name":"BitWell"},{"id":406,"name":"BitMart"},{"id":525,"name":"XT.COM"},{"id":482,"name":"BKEX"},
# ...
