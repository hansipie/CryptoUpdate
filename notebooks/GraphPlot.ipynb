# %% [markdown]
# # Graph crypto

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def rapport(tokenlist, all):
    df=pd.DataFrame(index=all.index)
    for t in tokenlist:
        df[t]=all[t]
    return df

# %% [markdown]
# Transformation des fichiers CSV en DataFrame

# %%
all = pd.read_csv("../outputs/ArchiveFinal.csv", index_col="Timestamp")
all = all.sort_index().reindex(sorted(all.columns), axis=1)
all.tail()
# Out:
#                      ANC        APE     ATLAS       ATOM       AVAX  \
# Timestamp
# 2023-03-27 01:14:57  0.0  59.645213  1.399495  74.052218  40.813459
# 2023-03-27 12:10:48  0.0  58.378522  1.379822  73.461519  40.149637
# 2023-03-27 14:43:43  0.0  58.173947  1.377873  73.475337  40.500586
# 2023-03-28 01:15:18  0.0  56.547044  1.342087  71.346568  39.318694
# 2023-03-28 12:52:35  0.0  67.915092  1.334325  71.880361  42.262268
#
#                            AXS       BCMC  BCOIN         BNB          BTC  \
# Timestamp
# 2023-03-27 01:14:57  44.704128  30.715462    0.0  416.687445  2873.950771
# 2023-03-27 12:10:48  43.780071  27.905925    0.0  416.460379  2877.016282
# 2023-03-27 14:43:43  43.841963  28.148168    0.0  417.803314  2886.891996
# 2023-03-28 01:15:18  42.251896  27.253334    0.0  391.216913  2798.352047
# 2023-03-28 12:52:35  52.240602  27.596869    0.0  393.333640  2818.030131
#
#                      ...       SEN       SHIB         SOL       TITA  \
# ...

# %% [markdown]
# ## Total

# %%
token='_Sum'
all[token].plot(figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='Timestamp'>

# %% [markdown]
# ## Le maitre: le Bitcoin

# %%
token='BTC'
all[token].plot(figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='Timestamp'>

# %% [markdown]
# ## ... et son dauphin: L'Etherum

# %%
token=['ETH']
all[token].plot(figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='Timestamp'>

# %% [markdown]
# ## Shit coin

# %%
tokenlist=['SHIB', 'DOGE']
df = rapport(tokenlist, all)
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='Timestamp'>

# %% [markdown]
# ## Stable coins

# %%
tokenlist=['BUSD', 'USDT']
df=rapport(tokenlist,all)
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='Timestamp'>

# %% [markdown]
# ## Les play 2 earn

# %%
tokenlist=['BCOIN', 'SAND', 'AXS', 'BCMC', 'ILV', 'PRL']
df=rapport(tokenlist,all)
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='Timestamp'>

# %%
tokenlist=['SEN']
df=rapport(tokenlist,all)
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='Timestamp'>

# %%
tokenlist=['ILV']
df=rapport(tokenlist,all)
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='Timestamp'>

# %%
tokenlist=['TITA']
df=rapport(tokenlist,all)
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='Timestamp'>

# %%
tokenlist=['ATLAS']
df = rapport(tokenlist, all)
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='Timestamp'>

# %%
tokenlist=['APE']
df = rapport(tokenlist, all)
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='Timestamp'>

# %% [markdown]
# ## Platformes

# %%
tokenlist = ['BNB','CAKE']
df = rapport(tokenlist, all)
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='Timestamp'>

# %%
tokenlist = ['ATOM']
df = rapport(tokenlist, all)
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='Timestamp'>

# %%
tokenlist = ['DOT']
df = rapport(tokenlist, all)
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='Timestamp'>

# %%
tokenlist = ['MATIC', 'MYST']
df = rapport(tokenlist, all)
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='Timestamp'>

# %%
tokenlist = ['SOL']
df = rapport(tokenlist, all)
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='Timestamp'>

# %%
tokenlist = ['TON']
df = rapport(tokenlist, all)
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='Timestamp'>

# %%
tokenlist = ['XRP']
df = rapport(tokenlist, all)
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='Timestamp'>

# %%
tokenlist = ['EGLD']
df = rapport(tokenlist, all)
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='Timestamp'>

# %%
tokenlist = ['LINK']
df = rapport(tokenlist, all)
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='Timestamp'>

# %% [markdown]
# ## Pie Chart

# %%
# read csv file
all = pd.read_csv("ArchiveFinal.csv")
# get last line
last = all.tail(1)
# clean table
last = last.drop(columns=['Timestamp'])
last = last.drop(columns=['_Sum'])
last = last.dropna(axis='columns')
last
# Out:
#      ANC     ATLAS        AXS       BCMC  BCOIN        BNB          BTC  BUSD  \
# 665  0.0  1.334325  52.240602  27.596869    0.0  393.33364  2818.030131   0.0
#
#            CAKE         ETH  ...      SHIB      ETHW        XRP       ATOM  \
# 665  151.252989  949.722993  ...  14.29204  1.096739  96.082147  71.880361
#
#            DOGE       IBAT       HFT        TON        LINK        D2T
# 665  133.679183  36.002581  0.666225  24.318682  106.222207  104.08635
#
# [1 rows x 42 columns]

# %%
values = last.values.tolist()[0]
labels = last.columns.tolist()

# %%
# draw pie
plt.figure(figsize=(10,10), facecolor='white')
ax1 = plt.subplot()
ax1.pie(values, labels=labels)
plt.show()
